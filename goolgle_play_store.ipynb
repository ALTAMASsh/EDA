# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as pg

# %%
df = pd.read_csv("/content/googleplaystore.csv")

# %%
df.tail()
# Out:
#       level_0  index                                            App  \
# 8270     8270  10834                                  FR Calculator
# 8271     8271  10836                               Sya9a Maroc - FR
# 8272     8272  10837               Fr. Mike Schmitz Audio Teachings
# 8273     8273  10839                  The SCP Foundation DB fr nn5n
# 8274     8274  10840  iHoroscope - 2018 Daily Horoscope & Astrology
#
#                  Category  Rating Reviews          Size     Installs  Type  \
# 8270               FAMILY     4.0       7  2.610,00,000         500+  Free
# 8271               FAMILY     4.5      38   5310,00,000       5,000+  Free
# 8272               FAMILY     5.0       4  3.610,00,000         100+  Free
# 8273  BOOKS_AND_REFERENCE     4.5     114           Nan       1,000+  Free
# 8274            LIFESTYLE     4.5  398307   1910,00,000  10,000,000+  Free
#
#       Price Content Rating             Genres      Last Updated  \
# ...

# %%
df.head()
# Out:
#    level_0  index                                                App  \
# 0        0      0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1        1      1                                Coloring book moana
# 2        2      2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3        3      3                              Sketch - Draw & Paint
# 4        4      4              Pixel Draw - Number Art Coloring Book
#
#          Category  Rating Reviews          Size     Installs  Type  Price  \
# 0  ART_AND_DESIGN     4.1     159   1910,00,000      10,000+  Free    0.0
# 1  ART_AND_DESIGN     3.9     967   1410,00,000     500,000+  Free    0.0
# 2  ART_AND_DESIGN     4.7   87510  8.710,00,000   5,000,000+  Free    0.0
# 3  ART_AND_DESIGN     4.5  215644   2510,00,000  50,000,000+  Free    0.0
# 4  ART_AND_DESIGN     4.3     967  2.810,00,000     100,000+  Free    0.0
#
#   Content Rating                     Genres      Last Updated  \
# ...

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df[df.duplicated].count()
df.drop_duplicates(inplace =True)

# %%
df[df.duplicated].count()

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df["Price"] = pd.to_numeric(df["Price"],errors = "coerce")

# %%
df.describe(include="all")
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1465
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price              766
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
df["Size"]=df["Size"].str.replace("M","0,00,000")

# %%
df["Size"]=df["Size"].str.replace("k","000")

# %%
df["Size"].value_counts()
# Out:
# Nan            1402
# 1310,00,000     149
# 1410,00,000     146
# 1210,00,000     142
# 1510,00,000     141
#                ...
# 4541000           1
# 8121000           1
# 4421000           1
# 8421000           1
# 6191000           1
# Name: Size, Length: 372, dtype: int64

# %%
df.columns
# Out:
# Index(['level_0', 'index', 'App', 'Category', 'Rating', 'Reviews', 'Size',
#        'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated',
#        'Current Ver', 'Android Ver'],
#       dtype='object')

# %%
df["Installs"] = df["Installs"].str.replace("Free","0")

# %%
fig=pg.Figure()
fig.add_traces(pg.Histogram(x = df['Installs']))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=pg.Figure()
fig.add_traces(pg.Scatter(x = df.Installs,y=df.Size,mode="markers",marker_size=12))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
categorical_feature=[feature for feature in df.columns if df[feature].dtype == "O"]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8275, step=1)

# %%
df.reset_index(drop=True, inplace=True)

# %%
len(df)
# Out:
# 8275

# %%
categorical_feature
# Out:
# ['App',
#  'Category',
#  'Reviews',
#  'Size',
#  'Installs',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
numerical_feature=[feature for feature in df.columns if df[feature].dtype != "O"]

# %%
numerical_feature
# Out:
# ['Rating', 'Price']

# %%
sns.kdeplot(df["Rating"])
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
sns.histplot(df["Rating"])
# Out:
# <Axes: xlabel='Rating', ylabel='Count'>

# %%
plt.figure(figsize=(20,15))
plotnumber =1
for col in numerical_feature:
  if plotnumber>=15:
    ax = plt.subplot(3,5,plotnumber)
    sns.displot(df[col])
  plotnumber+=1
plt.tight_layout()
plt.show()

# %%
df["Category"].value_counts().plot.pie(y = df['Category'],autopct="%1.1f%%",figsize = (12,12))
# Out:
# <Axes: ylabel='Category'>

# %%
corr = df[numerical_feature].corr()
sns.heatmap(corr, cmap="Blues",annot=True)
# Out:
# <Axes: >
